# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Keyhan Hodaei
# Student-ID: 401106696

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display
# Out:
# 2024-11-22 16:37:46.955567: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-22 16:37:46.963632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-22 16:37:46.973287: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-22 16:37:46.976240: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-22 16:37:46.984876: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-22 16:37:47.621140: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y_new, train_size=60000, random_state=SEED)

# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # Do the same for other activation functions

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - ((np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x)))**2
        else:
            return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.exp(-x) / (1+np.exp(-x))**2
        else:
            return 1 / (1+np.exp(-x))
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        e_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return e_x / np.sum(e_x, axis=1, keepdims=True)
        
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha)
        else:
            return np.where(x > 0, x, alpha*x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha*np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x)-1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha*np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x)-1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params


    def feed_forward(self, x):
        self.cache["A0"] = x
        # -------------------------------- TODO -------------------------------------
        for i in range(1, self.num_layers + 1):
            W_i = self.params[f"W{i}"]
            b_i = self.params[f"b{i}"]
            
            Z_i = np.dot(self.cache[f'A{i-1}'], W_i.T) + b_i.T
            self.cache[f'Z{i}'] = Z_i

            if i == self.num_layers:
                self.cache[f'A{i}'] = self.softmax(Z_i)
            else:
                self.cache[f'A{i}'] = self.activation(Z_i)
        # -------------------------------- TODO -------------------------------------
        return self.cache[f"A{self.num_layers}"]


    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}
        
        # -------------------------------- TODO -------------------------------------
        dA = output - y
        for i in range(self.num_layers, 0, -1):
            Z_i = self.cache[f'Z{i}']
            A_prev = self.cache[f'A{i-1}']
            
            dZ = dA * self.activation(Z_i, derivative=True)
            dW_i = np.dot(dZ.T, A_prev) / current_batch_size
            db_i = np.sum(dZ, axis=0, keepdims=True).T / current_batch_size
            
            grads[f'W{i}'] = dW_i
            grads[f'b{i}'] = db_i

            if i > 1:
                dA = np.dot(dZ, self.params[f"W{i}"])
        # -------------------------------- TODO -------------------------------------
            
        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        m = y.shape[0]
        epsilon = 1e-10
        l = -np.sum(y * np.log(output + epsilon)) / m
        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f'W{i}'] = np.zeros_like(self.params[f'W{i}'])
            momemtum_opt[f'b{i}'] = np.zeros_like(self.params[f'b{i}'])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {'m': {}, 'v': {}}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt['m'][f'W{i}'] = np.zeros_like(self.params[f'W{i}'])
            adam_opt['m'][f'b{i}'] = np.zeros_like(self.params[f'b{i}'])
            adam_opt['v'][f'W{i}'] = np.zeros_like(self.params[f'W{i}'])
            adam_opt['v'][f'b{i}'] = np.zeros_like(self.params[f'b{i}'])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                self.momemtum_opt[key] = beta * self.momemtum_opt[key] + (1-beta) * self.grads[key]
                self.params[key] -= l_rate * self.momemtum_opt[key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                self.adam_opt['m'][key] = beta1 * self.adam_opt['m'][key] + (1-beta1) * self.grads[key]
                self.adam_opt['v'][key] = beta2 * self.adam_opt['v'][key] + (1-beta2) * (self.grads[key]**2)
                m_hat = self.adam_opt['m'][key] / (1 - beta1**t)
                v_hat = self.adam_opt['v'][key] / (1 - beta2**t)
                self.params[key] -= l_rate * m_hat / (np.sqrt(v_hat) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        pred = np.argmax(output, axis=1)
        label = np.argmax(y, axis=1)
        return np.mean(pred == label)
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')
    
    ''' I modified the evaluate method, so I could use it to take the accuracy and loss of the test data '''
    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')
        return test_acc, test_loss

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...
n_epochs = 20
l_rate1, l_rate2 = 0.01, 0.001
batch_size = 64
sizes = [784, 128, 64, 10]
activations = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
optimizers = ['sgd', 'momentum', 'adam']

best_model = None
best_acc, best_loss = 0, float('inf')
for activation in activations:
    for optimizer in optimizers:
        for l_rate in [l_rate1, l_rate2]:
            print(f'\n\nActivation: {activation}, Optimizer: {optimizer}, Learning Rate: {l_rate}')
            mlp = MLP(sizes, activation=activation)
            mlp.train(x_train, y_train, x_test, y_test, epochs=n_epochs, batch_size=batch_size, optimizer=optimizer, l_rate=l_rate)
            acc, loss = mlp.evaluate(x_test, y_test)
            if acc > best_acc:
                best_acc = acc
                best_loss = loss
                best_model = (activation, optimizer, l_rate)
                
print(f'\n\nBest model: {best_model}, Accuracy: {best_acc}, Loss: {best_loss}')
# Out:
# Activation: relu, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 2.26s, train acc=0.69, train loss=1.10, validation acc=0.68, validation loss=1.12
# Epoch 2: 4.23s, train acc=0.72, train loss=0.87, validation acc=0.71, validation loss=0.89
# Epoch 3: 5.98s, train acc=0.74, train loss=0.77, validation acc=0.73, validation loss=0.80
# Epoch 4: 7.64s, train acc=0.75, train loss=0.70, validation acc=0.74, validation loss=0.74
# Epoch 5: 9.12s, train acc=0.76, train loss=0.68, validation acc=0.75, validation loss=0.72
# Epoch 6: 10.52s, train acc=0.76, train loss=0.65, validation acc=0.75, validation loss=0.69
# Epoch 7: 11.93s, train acc=0.77, train loss=0.64, validation acc=0.76, validation loss=0.67
# Epoch 8: 13.30s, train acc=0.77, train loss=0.61, validation acc=0.76, validation loss=0.65
# Epoch 9: 14.52s, train acc=0.78, train loss=0.59, validation acc=0.77, validation loss=0.62
# Epoch 10: 15.68s, train acc=0.79, train loss=0.56, validation acc=0.78, validation loss=0.60
# Epoch 11: 16.85s, train acc=0.78, train loss=0.57, validation acc=0.77, validation loss=0.61
# Epoch 12: 18.05s, train acc=0.79, train loss=0.55, validation acc=0.78, validation loss=0.60
# Epoch 13: 19.19s, train acc=0.79, train loss=0.53, validation acc=0.78, validation loss=0.57
# Epoch 14: 20.58s, train acc=0.80, train loss=0.52, validation acc=0.78, validation loss=0.56
# Epoch 15: 21.75s, train acc=0.80, train loss=0.51, validation acc=0.79, validation loss=0.56
# Epoch 16: 22.93s, train acc=0.80, train loss=0.51, validation acc=0.78, validation loss=0.55
# Epoch 17: 24.25s, train acc=0.80, train loss=0.50, validation acc=0.79, validation loss=0.54
# Epoch 18: 25.45s, train acc=0.80, train loss=0.50, validation acc=0.79, validation loss=0.54
# Epoch 19: 26.72s, train acc=0.81, train loss=0.48, validation acc=0.79, validation loss=0.52
# Epoch 20: 27.93s, train acc=0.81, train loss=0.47, validation acc=0.79, validation loss=0.52
#
# Test acc=0.79, Test loss=0.52
#
#
# Activation: relu, Optimizer: sgd, Learning Rate: 0.001
# Epoch 1: 1.20s, train acc=0.35, train loss=2.17, validation acc=0.34, validation loss=2.17
# Epoch 2: 2.54s, train acc=0.48, train loss=1.94, validation acc=0.47, validation loss=1.95
# Epoch 3: 3.70s, train acc=0.62, train loss=1.66, validation acc=0.61, validation loss=1.68
# Epoch 4: 4.88s, train acc=0.69, train loss=1.41, validation acc=0.68, validation loss=1.44
# Epoch 5: 6.07s, train acc=0.73, train loss=1.24, validation acc=0.71, validation loss=1.27
# Epoch 6: 7.55s, train acc=0.76, train loss=1.12, validation acc=0.74, validation loss=1.16
# Epoch 7: 9.15s, train acc=0.77, train loss=1.04, validation acc=0.76, validation loss=1.08
# Epoch 8: 10.63s, train acc=0.78, train loss=0.98, validation acc=0.77, validation loss=1.02
# Epoch 9: 12.09s, train acc=0.79, train loss=0.93, validation acc=0.78, validation loss=0.98
# Epoch 10: 13.61s, train acc=0.80, train loss=0.89, validation acc=0.79, validation loss=0.94
# Epoch 11: 15.05s, train acc=0.80, train loss=0.87, validation acc=0.79, validation loss=0.91
# Epoch 12: 16.56s, train acc=0.81, train loss=0.84, validation acc=0.79, validation loss=0.89
# Epoch 13: 18.07s, train acc=0.81, train loss=0.82, validation acc=0.80, validation loss=0.87
# Epoch 14: 19.65s, train acc=0.81, train loss=0.80, validation acc=0.80, validation loss=0.85
# Epoch 15: 21.11s, train acc=0.81, train loss=0.79, validation acc=0.80, validation loss=0.84
# Epoch 16: 22.51s, train acc=0.82, train loss=0.78, validation acc=0.80, validation loss=0.83
# Epoch 17: 24.16s, train acc=0.82, train loss=0.76, validation acc=0.80, validation loss=0.81
# Epoch 18: 25.71s, train acc=0.82, train loss=0.75, validation acc=0.81, validation loss=0.81
# Epoch 19: 27.19s, train acc=0.82, train loss=0.74, validation acc=0.81, validation loss=0.80
# Epoch 20: 28.69s, train acc=0.82, train loss=0.74, validation acc=0.81, validation loss=0.79
#
# Test acc=0.81, Test loss=0.79
#
#
# Activation: relu, Optimizer: momentum, Learning Rate: 0.01
# Epoch 1: 1.68s, train acc=0.78, train loss=0.84, validation acc=0.77, validation loss=0.88
# Epoch 2: 3.36s, train acc=0.81, train loss=0.62, validation acc=0.80, validation loss=0.67
# Epoch 3: 4.97s, train acc=0.83, train loss=0.53, validation acc=0.82, validation loss=0.57
# Epoch 4: 6.67s, train acc=0.84, train loss=0.48, validation acc=0.83, validation loss=0.53
# Epoch 5: 8.34s, train acc=0.86, train loss=0.44, validation acc=0.84, validation loss=0.49
# Epoch 6: 10.06s, train acc=0.86, train loss=0.42, validation acc=0.85, validation loss=0.47
# Epoch 7: 11.66s, train acc=0.88, train loss=0.39, validation acc=0.86, validation loss=0.44
# Epoch 8: 13.40s, train acc=0.88, train loss=0.37, validation acc=0.87, validation loss=0.42
# Epoch 9: 15.15s, train acc=0.88, train loss=0.37, validation acc=0.86, validation loss=0.42
# Epoch 10: 16.88s, train acc=0.89, train loss=0.34, validation acc=0.88, validation loss=0.40
# Epoch 11: 18.82s, train acc=0.89, train loss=0.35, validation acc=0.87, validation loss=0.40
# Epoch 12: 20.63s, train acc=0.90, train loss=0.33, validation acc=0.88, validation loss=0.39
# Epoch 13: 22.41s, train acc=0.90, train loss=0.32, validation acc=0.89, validation loss=0.37
# Epoch 14: 24.21s, train acc=0.91, train loss=0.30, validation acc=0.89, validation loss=0.36
# Epoch 15: 26.12s, train acc=0.91, train loss=0.30, validation acc=0.89, validation loss=0.36
# Epoch 16: 27.96s, train acc=0.91, train loss=0.29, validation acc=0.89, validation loss=0.35
# Epoch 17: 29.79s, train acc=0.91, train loss=0.29, validation acc=0.89, validation loss=0.35
# Epoch 18: 31.61s, train acc=0.92, train loss=0.28, validation acc=0.90, validation loss=0.33
# Epoch 19: 33.52s, train acc=0.92, train loss=0.27, validation acc=0.90, validation loss=0.33
# Epoch 20: 35.38s, train acc=0.92, train loss=0.27, validation acc=0.90, validation loss=0.33
#
# Test acc=0.90, Test loss=0.33
#
#
# Activation: relu, Optimizer: momentum, Learning Rate: 0.001
# Epoch 1: 1.65s, train acc=0.43, train loss=2.17, validation acc=0.42, validation loss=2.17
# Epoch 2: 3.36s, train acc=0.64, train loss=1.89, validation acc=0.63, validation loss=1.89
# Epoch 3: 5.37s, train acc=0.72, train loss=1.50, validation acc=0.70, validation loss=1.51
# Epoch 4: 7.34s, train acc=0.78, train loss=1.14, validation acc=0.76, validation loss=1.16
# Epoch 5: 9.15s, train acc=0.81, train loss=0.90, validation acc=0.80, validation loss=0.91
# Epoch 6: 12.48s, train acc=0.83, train loss=0.74, validation acc=0.83, validation loss=0.76
# Epoch 7: 15.01s, train acc=0.84, train loss=0.65, validation acc=0.84, validation loss=0.67
# Epoch 8: 16.81s, train acc=0.85, train loss=0.58, validation acc=0.85, validation loss=0.61
# Epoch 9: 18.76s, train acc=0.86, train loss=0.54, validation acc=0.86, validation loss=0.56
# Epoch 10: 20.74s, train acc=0.87, train loss=0.50, validation acc=0.86, validation loss=0.53
# Epoch 11: 22.63s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 12: 24.61s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 13: 26.54s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 14: 28.43s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 15: 30.22s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 16: 32.17s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 17: 33.95s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 18: 35.78s, train acc=0.89, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 19: 37.72s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 20: 39.72s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
#
# Test acc=0.89, Test loss=0.40
#
#
# Activation: relu, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 2.44s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 2: 5.08s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 3: 10.91s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 4: 15.18s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 5: 17.73s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 6: 20.31s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 7: 22.75s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 8: 29.92s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 9: 37.49s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 10: 45.14s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 11: 52.50s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 12: 59.99s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 13: 67.45s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 14: 74.82s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 15: 82.21s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 16: 89.52s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 17: 97.09s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 18: 104.55s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 19: 112.10s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
# Epoch 20: 119.45s, train acc=0.10, train loss=17.89, validation acc=0.11, validation loss=17.70
#
# Test acc=0.11, Test loss=17.70
#
#
# Activation: relu, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 2.59s, train acc=0.59, train loss=1.50, validation acc=0.57, validation loss=1.55
# Epoch 2: 5.32s, train acc=0.60, train loss=1.42, validation acc=0.58, validation loss=1.47
# Epoch 3: 7.92s, train acc=0.62, train loss=1.26, validation acc=0.60, validation loss=1.31
# Epoch 4: 10.51s, train acc=0.61, train loss=1.25, validation acc=0.60, validation loss=1.31
# Epoch 5: 13.05s, train acc=0.63, train loss=1.21, validation acc=0.61, validation loss=1.26
# Epoch 6: 15.69s, train acc=0.63, train loss=1.20, validation acc=0.61, validation loss=1.26
# Epoch 7: 18.29s, train acc=0.63, train loss=1.19, validation acc=0.61, validation loss=1.25
# Epoch 8: 21.24s, train acc=0.64, train loss=1.15, validation acc=0.62, validation loss=1.21
# Epoch 9: 24.23s, train acc=0.64, train loss=1.07, validation acc=0.62, validation loss=1.13
# Epoch 10: 27.22s, train acc=0.63, train loss=1.11, validation acc=0.62, validation loss=1.17
# Epoch 11: 30.34s, train acc=0.65, train loss=1.12, validation acc=0.63, validation loss=1.19
# Epoch 12: 33.45s, train acc=0.63, train loss=1.18, validation acc=0.62, validation loss=1.25
# Epoch 13: 36.67s, train acc=0.65, train loss=1.08, validation acc=0.63, validation loss=1.15
# Epoch 14: 39.91s, train acc=0.64, train loss=1.08, validation acc=0.63, validation loss=1.15
# Epoch 15: 47.64s, train acc=0.65, train loss=1.10, validation acc=0.63, validation loss=1.18
# Epoch 16: 54.71s, train acc=0.64, train loss=1.08, validation acc=0.63, validation loss=1.15
# Epoch 17: 57.89s, train acc=0.63, train loss=1.16, validation acc=0.62, validation loss=1.23
# Epoch 18: 61.07s, train acc=0.65, train loss=1.07, validation acc=0.63, validation loss=1.15
# Epoch 19: 64.36s, train acc=0.65, train loss=1.05, validation acc=0.63, validation loss=1.12
# Epoch 20: 67.54s, train acc=0.65, train loss=1.00, validation acc=0.64, validation loss=1.08
#
# Test acc=0.64, Test loss=1.08
#
#
# Activation: sigmoid, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 1.94s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 2: 5.17s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 3: 6.99s, train acc=0.13, train loss=2.27, validation acc=0.12, validation loss=2.27
# Epoch 4: 8.92s, train acc=0.15, train loss=2.25, validation acc=0.15, validation loss=2.25
# Epoch 5: 10.97s, train acc=0.34, train loss=2.24, validation acc=0.34, validation loss=2.24
# Epoch 6: 12.91s, train acc=0.36, train loss=2.22, validation acc=0.36, validation loss=2.22
# Epoch 7: 14.87s, train acc=0.51, train loss=2.20, validation acc=0.50, validation loss=2.20
# Epoch 8: 18.12s, train acc=0.51, train loss=2.17, validation acc=0.50, validation loss=2.17
# Epoch 9: 20.05s, train acc=0.54, train loss=2.14, validation acc=0.53, validation loss=2.14
# Epoch 10: 22.06s, train acc=0.56, train loss=2.10, validation acc=0.55, validation loss=2.10
# Epoch 11: 24.04s, train acc=0.61, train loss=2.05, validation acc=0.60, validation loss=2.05
# Epoch 12: 26.04s, train acc=0.60, train loss=1.99, validation acc=0.59, validation loss=2.00
# Epoch 13: 28.03s, train acc=0.62, train loss=1.93, validation acc=0.61, validation loss=1.93
# Epoch 14: 29.97s, train acc=0.63, train loss=1.86, validation acc=0.61, validation loss=1.86
# Epoch 15: 32.07s, train acc=0.63, train loss=1.78, validation acc=0.62, validation loss=1.79
# Epoch 16: 33.98s, train acc=0.65, train loss=1.71, validation acc=0.63, validation loss=1.72
# Epoch 17: 35.92s, train acc=0.65, train loss=1.64, validation acc=0.64, validation loss=1.64
# Epoch 18: 37.94s, train acc=0.66, train loss=1.57, validation acc=0.65, validation loss=1.58
# Epoch 19: 39.86s, train acc=0.67, train loss=1.51, validation acc=0.67, validation loss=1.51
# Epoch 20: 41.87s, train acc=0.69, train loss=1.45, validation acc=0.68, validation loss=1.46
#
# Test acc=0.68, Test loss=1.46
#
#
# Activation: sigmoid, Optimizer: sgd, Learning Rate: 0.001
# Epoch 1: 2.09s, train acc=0.10, train loss=2.33, validation acc=0.10, validation loss=2.33
# Epoch 2: 4.15s, train acc=0.10, train loss=2.31, validation acc=0.10, validation loss=2.31
# Epoch 3: 6.14s, train acc=0.13, train loss=2.30, validation acc=0.13, validation loss=2.30
# Epoch 4: 8.27s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 5: 10.70s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 6: 12.68s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 7: 15.18s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 8: 17.18s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 9: 19.12s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 10: 21.02s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 11: 24.18s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 12: 26.08s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 13: 28.00s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 14: 29.92s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 15: 31.83s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 16: 33.82s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 17: 35.81s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 18: 37.79s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 19: 39.79s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 20: 41.74s, train acc=0.11, train loss=2.27, validation acc=0.11, validation loss=2.28
#
# Test acc=0.11, Test loss=2.28
#
#
# Activation: sigmoid, Optimizer: momentum, Learning Rate: 0.01
# Epoch 1: 2.13s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 2: 4.30s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 3: 6.55s, train acc=0.16, train loss=2.27, validation acc=0.15, validation loss=2.27
# Epoch 4: 8.84s, train acc=0.23, train loss=2.26, validation acc=0.22, validation loss=2.26
# Epoch 5: 11.98s, train acc=0.29, train loss=2.25, validation acc=0.29, validation loss=2.25
# Epoch 6: 14.17s, train acc=0.36, train loss=2.23, validation acc=0.36, validation loss=2.23
# Epoch 7: 16.29s, train acc=0.40, train loss=2.21, validation acc=0.39, validation loss=2.21
# Epoch 8: 18.42s, train acc=0.39, train loss=2.19, validation acc=0.39, validation loss=2.19
# Epoch 9: 20.60s, train acc=0.44, train loss=2.16, validation acc=0.43, validation loss=2.17
# Epoch 10: 22.84s, train acc=0.49, train loss=2.13, validation acc=0.48, validation loss=2.13
# Epoch 11: 25.01s, train acc=0.50, train loss=2.09, validation acc=0.49, validation loss=2.09
# Epoch 12: 27.26s, train acc=0.53, train loss=2.05, validation acc=0.52, validation loss=2.05
# Epoch 13: 29.40s, train acc=0.56, train loss=1.99, validation acc=0.55, validation loss=1.99
# Epoch 14: 31.56s, train acc=0.57, train loss=1.93, validation acc=0.56, validation loss=1.93
# Epoch 15: 33.70s, train acc=0.58, train loss=1.86, validation acc=0.58, validation loss=1.87
# Epoch 16: 35.90s, train acc=0.60, train loss=1.79, validation acc=0.59, validation loss=1.79
# Epoch 17: 38.12s, train acc=0.61, train loss=1.72, validation acc=0.61, validation loss=1.72
# Epoch 18: 40.22s, train acc=0.63, train loss=1.64, validation acc=0.62, validation loss=1.65
# Epoch 19: 42.41s, train acc=0.64, train loss=1.57, validation acc=0.64, validation loss=1.58
# Epoch 20: 44.48s, train acc=0.65, train loss=1.50, validation acc=0.65, validation loss=1.51
#
# Test acc=0.65, Test loss=1.51
#
#
# Activation: sigmoid, Optimizer: momentum, Learning Rate: 0.001
# Epoch 1: 2.12s, train acc=0.09, train loss=2.37, validation acc=0.09, validation loss=2.37
# Epoch 2: 4.21s, train acc=0.12, train loss=2.33, validation acc=0.11, validation loss=2.33
# Epoch 3: 6.47s, train acc=0.11, train loss=2.31, validation acc=0.11, validation loss=2.32
# Epoch 4: 8.77s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.31
# Epoch 5: 10.96s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 6: 13.13s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 7: 15.36s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.30
# Epoch 8: 17.67s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 9: 19.93s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 10: 22.08s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 11: 24.31s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 12: 26.45s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 13: 28.67s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 14: 30.89s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 15: 33.06s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 16: 35.25s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 17: 39.23s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 18: 41.44s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 19: 45.34s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 20: 47.52s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
#
# Test acc=0.12, Test loss=2.28
#
#
# Activation: sigmoid, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 6.41s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 2: 9.36s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 3: 12.39s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 4: 15.62s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 5: 18.69s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 6: 25.08s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 7: 28.14s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 8: 31.19s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 9: 37.90s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 10: 40.91s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 11: 43.91s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 12: 47.06s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 13: 50.08s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 14: 53.07s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 15: 56.33s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 16: 60.61s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 17: 63.66s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 18: 66.72s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 19: 69.68s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.17
# Epoch 20: 72.67s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.15
#
# Test acc=0.97, Test loss=0.15
#
#
# Activation: sigmoid, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 3.02s, train acc=0.91, train loss=0.37, validation acc=0.90, validation loss=0.40
# Epoch 2: 9.73s, train acc=0.93, train loss=0.27, validation acc=0.92, validation loss=0.31
# Epoch 3: 12.77s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.27
# Epoch 4: 15.80s, train acc=0.95, train loss=0.20, validation acc=0.94, validation loss=0.24
# Epoch 5: 18.91s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.22
# Epoch 6: 21.95s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 7: 25.55s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 8: 28.67s, train acc=0.97, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 9: 31.82s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 10: 34.99s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 11: 37.96s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 12: 40.93s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 13: 44.04s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 14: 47.11s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 15: 50.12s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.13
# Epoch 16: 53.06s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 17: 56.06s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 18: 59.18s, train acc=0.99, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 19: 62.20s, train acc=0.99, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 20: 65.12s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
#
# Test acc=0.97, Test loss=0.11
#
#
# Activation: tanh, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 2.80s, train acc=0.87, train loss=0.86, validation acc=0.86, validation loss=0.88
# Epoch 2: 5.52s, train acc=0.89, train loss=0.64, validation acc=0.88, validation loss=0.67
# Epoch 3: 8.33s, train acc=0.90, train loss=0.54, validation acc=0.89, validation loss=0.57
# Epoch 4: 11.08s, train acc=0.91, train loss=0.48, validation acc=0.90, validation loss=0.51
# Epoch 5: 13.87s, train acc=0.91, train loss=0.44, validation acc=0.90, validation loss=0.47
# Epoch 6: 16.72s, train acc=0.92, train loss=0.41, validation acc=0.90, validation loss=0.44
# Epoch 7: 19.56s, train acc=0.92, train loss=0.38, validation acc=0.91, validation loss=0.42
# Epoch 8: 22.47s, train acc=0.92, train loss=0.36, validation acc=0.91, validation loss=0.40
# Epoch 9: 25.16s, train acc=0.93, train loss=0.35, validation acc=0.91, validation loss=0.38
# Epoch 10: 28.11s, train acc=0.93, train loss=0.33, validation acc=0.91, validation loss=0.37
# Epoch 11: 30.96s, train acc=0.93, train loss=0.32, validation acc=0.92, validation loss=0.35
# Epoch 12: 33.74s, train acc=0.93, train loss=0.31, validation acc=0.92, validation loss=0.34
# Epoch 13: 36.53s, train acc=0.93, train loss=0.30, validation acc=0.92, validation loss=0.34
# Epoch 14: 39.32s, train acc=0.94, train loss=0.29, validation acc=0.92, validation loss=0.33
# Epoch 15: 42.15s, train acc=0.94, train loss=0.28, validation acc=0.92, validation loss=0.32
# Epoch 16: 44.98s, train acc=0.94, train loss=0.28, validation acc=0.93, validation loss=0.31
# Epoch 17: 47.79s, train acc=0.94, train loss=0.27, validation acc=0.93, validation loss=0.31
# Epoch 18: 50.57s, train acc=0.94, train loss=0.26, validation acc=0.93, validation loss=0.30
# Epoch 19: 53.37s, train acc=0.94, train loss=0.26, validation acc=0.93, validation loss=0.29
# Epoch 20: 56.17s, train acc=0.94, train loss=0.25, validation acc=0.93, validation loss=0.29
#
# Test acc=0.93, Test loss=0.29
#
#
# Activation: tanh, Optimizer: sgd, Learning Rate: 0.001
# Epoch 1: 2.82s, train acc=0.65, train loss=1.78, validation acc=0.63, validation loss=1.79
# Epoch 2: 5.59s, train acc=0.75, train loss=1.51, validation acc=0.73, validation loss=1.52
# Epoch 3: 8.49s, train acc=0.79, train loss=1.34, validation acc=0.77, validation loss=1.36
# Epoch 4: 11.36s, train acc=0.81, train loss=1.23, validation acc=0.80, validation loss=1.24
# Epoch 5: 14.18s, train acc=0.83, train loss=1.14, validation acc=0.81, validation loss=1.16
# Epoch 6: 17.06s, train acc=0.84, train loss=1.07, validation acc=0.83, validation loss=1.09
# Epoch 7: 19.95s, train acc=0.84, train loss=1.01, validation acc=0.83, validation loss=1.03
# Epoch 8: 22.85s, train acc=0.85, train loss=0.96, validation acc=0.84, validation loss=0.98
# Epoch 9: 25.48s, train acc=0.86, train loss=0.92, validation acc=0.84, validation loss=0.94
# Epoch 10: 28.28s, train acc=0.86, train loss=0.88, validation acc=0.85, validation loss=0.90
# Epoch 11: 31.16s, train acc=0.87, train loss=0.85, validation acc=0.85, validation loss=0.87
# Epoch 12: 33.88s, train acc=0.87, train loss=0.82, validation acc=0.86, validation loss=0.84
# Epoch 13: 36.64s, train acc=0.87, train loss=0.79, validation acc=0.86, validation loss=0.82
# Epoch 14: 39.47s, train acc=0.88, train loss=0.77, validation acc=0.86, validation loss=0.79
# Epoch 15: 42.34s, train acc=0.88, train loss=0.75, validation acc=0.87, validation loss=0.77
# Epoch 16: 45.24s, train acc=0.88, train loss=0.73, validation acc=0.87, validation loss=0.75
# Epoch 17: 48.07s, train acc=0.88, train loss=0.71, validation acc=0.87, validation loss=0.73
# Epoch 18: 50.80s, train acc=0.89, train loss=0.69, validation acc=0.87, validation loss=0.72
# Epoch 19: 53.75s, train acc=0.89, train loss=0.67, validation acc=0.88, validation loss=0.70
# Epoch 20: 56.54s, train acc=0.89, train loss=0.66, validation acc=0.88, validation loss=0.68
#
# Test acc=0.88, Test loss=0.68
#
#
# Activation: tanh, Optimizer: momentum, Learning Rate: 0.01
# Epoch 1: 3.13s, train acc=0.87, train loss=0.85, validation acc=0.86, validation loss=0.87
# Epoch 2: 6.12s, train acc=0.89, train loss=0.64, validation acc=0.88, validation loss=0.67
# Epoch 3: 9.15s, train acc=0.90, train loss=0.54, validation acc=0.89, validation loss=0.57
# Epoch 4: 12.27s, train acc=0.91, train loss=0.48, validation acc=0.89, validation loss=0.51
# Epoch 5: 15.29s, train acc=0.91, train loss=0.44, validation acc=0.90, validation loss=0.47
# Epoch 6: 18.37s, train acc=0.92, train loss=0.41, validation acc=0.90, validation loss=0.44
# Epoch 7: 21.39s, train acc=0.92, train loss=0.38, validation acc=0.91, validation loss=0.42
# Epoch 8: 24.36s, train acc=0.92, train loss=0.36, validation acc=0.91, validation loss=0.40
# Epoch 9: 27.38s, train acc=0.92, train loss=0.35, validation acc=0.91, validation loss=0.38
# Epoch 10: 30.42s, train acc=0.93, train loss=0.33, validation acc=0.91, validation loss=0.37
# Epoch 11: 33.47s, train acc=0.93, train loss=0.32, validation acc=0.91, validation loss=0.36
# Epoch 12: 36.50s, train acc=0.93, train loss=0.31, validation acc=0.92, validation loss=0.35
# Epoch 13: 39.61s, train acc=0.93, train loss=0.30, validation acc=0.92, validation loss=0.34
# Epoch 14: 42.72s, train acc=0.93, train loss=0.29, validation acc=0.92, validation loss=0.33
# Epoch 15: 45.68s, train acc=0.94, train loss=0.28, validation acc=0.92, validation loss=0.32
# Epoch 16: 48.76s, train acc=0.94, train loss=0.28, validation acc=0.92, validation loss=0.31
# Epoch 17: 51.79s, train acc=0.94, train loss=0.27, validation acc=0.93, validation loss=0.31
# Epoch 18: 55.01s, train acc=0.94, train loss=0.26, validation acc=0.93, validation loss=0.30
# Epoch 19: 58.12s, train acc=0.94, train loss=0.26, validation acc=0.93, validation loss=0.29
# Epoch 20: 61.13s, train acc=0.94, train loss=0.25, validation acc=0.93, validation loss=0.29
#
# Test acc=0.93, Test loss=0.29
#
#
# Activation: tanh, Optimizer: momentum, Learning Rate: 0.001
# Epoch 1: 3.20s, train acc=0.65, train loss=1.74, validation acc=0.65, validation loss=1.75
# Epoch 2: 6.23s, train acc=0.76, train loss=1.48, validation acc=0.75, validation loss=1.49
# Epoch 3: 9.11s, train acc=0.80, train loss=1.33, validation acc=0.78, validation loss=1.34
# Epoch 4: 12.04s, train acc=0.82, train loss=1.22, validation acc=0.81, validation loss=1.24
# Epoch 5: 15.08s, train acc=0.83, train loss=1.14, validation acc=0.82, validation loss=1.16
# Epoch 6: 18.11s, train acc=0.84, train loss=1.07, validation acc=0.83, validation loss=1.09
# Epoch 7: 21.05s, train acc=0.85, train loss=1.02, validation acc=0.84, validation loss=1.04
# Epoch 8: 24.05s, train acc=0.86, train loss=0.97, validation acc=0.84, validation loss=0.99
# Epoch 9: 27.06s, train acc=0.86, train loss=0.93, validation acc=0.85, validation loss=0.95
# Epoch 10: 30.11s, train acc=0.87, train loss=0.89, validation acc=0.85, validation loss=0.91
# Epoch 11: 33.07s, train acc=0.87, train loss=0.86, validation acc=0.85, validation loss=0.88
# Epoch 12: 36.18s, train acc=0.87, train loss=0.83, validation acc=0.86, validation loss=0.85
# Epoch 13: 39.34s, train acc=0.88, train loss=0.80, validation acc=0.86, validation loss=0.83
# Epoch 14: 42.47s, train acc=0.88, train loss=0.78, validation acc=0.86, validation loss=0.80
# Epoch 15: 45.50s, train acc=0.88, train loss=0.76, validation acc=0.87, validation loss=0.78
# Epoch 16: 48.65s, train acc=0.88, train loss=0.74, validation acc=0.87, validation loss=0.76
# Epoch 17: 53.02s, train acc=0.88, train loss=0.72, validation acc=0.87, validation loss=0.74
# Epoch 18: 56.10s, train acc=0.89, train loss=0.70, validation acc=0.87, validation loss=0.73
# Epoch 19: 59.35s, train acc=0.89, train loss=0.68, validation acc=0.88, validation loss=0.71
# Epoch 20: 62.47s, train acc=0.89, train loss=0.67, validation acc=0.88, validation loss=0.69
#
# Test acc=0.88, Test loss=0.69
#
#
# Activation: tanh, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 3.81s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 2: 7.85s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 3: 15.09s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.18
# Epoch 4: 18.95s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.17
# Epoch 5: 22.82s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.17
# Epoch 6: 26.61s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.18
# Epoch 7: 30.55s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.19
# Epoch 8: 34.38s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.19
# Epoch 9: 38.18s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.19
# Epoch 10: 42.08s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.21
# Epoch 11: 45.87s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.21
# Epoch 12: 49.64s, train acc=0.95, train loss=0.17, validation acc=0.93, validation loss=0.25
# Epoch 13: 53.60s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.23
# Epoch 14: 57.58s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.22
# Epoch 15: 61.61s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.25
# Epoch 16: 65.54s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.22
# Epoch 17: 69.45s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.31
# Epoch 18: 73.27s, train acc=0.87, train loss=0.42, validation acc=0.86, validation loss=0.49
# Epoch 19: 77.09s, train acc=0.92, train loss=0.31, validation acc=0.90, validation loss=0.39
# Epoch 20: 81.02s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.43
#
# Test acc=0.90, Test loss=0.43
#
#
# Activation: tanh, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 3.87s, train acc=0.94, train loss=0.26, validation acc=0.93, validation loss=0.30
# Epoch 2: 7.63s, train acc=0.96, train loss=0.20, validation acc=0.95, validation loss=0.23
# Epoch 3: 11.39s, train acc=0.97, train loss=0.16, validation acc=0.95, validation loss=0.20
# Epoch 4: 15.22s, train acc=0.97, train loss=0.14, validation acc=0.96, validation loss=0.18
# Epoch 5: 19.73s, train acc=0.98, train loss=0.12, validation acc=0.96, validation loss=0.16
# Epoch 6: 23.70s, train acc=0.98, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 7: 27.62s, train acc=0.98, train loss=0.09, validation acc=0.97, validation loss=0.13
# Epoch 8: 31.74s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.13
# Epoch 9: 35.68s, train acc=0.99, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 10: 41.19s, train acc=0.99, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 11: 46.99s, train acc=0.99, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 12: 50.68s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 13: 54.39s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 14: 58.49s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 15: 62.36s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 16: 66.20s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 17: 70.10s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 18: 73.90s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 19: 77.60s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 20: 81.51s, train acc=1.00, train loss=0.03, validation acc=0.97, validation loss=0.09
#
# Test acc=0.97, Test loss=0.09
#
#
# Activation: leaky_relu, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 1.68s, train acc=0.80, train loss=0.75, validation acc=0.79, validation loss=0.79
# Epoch 2: 3.37s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.43
# Epoch 3: 5.02s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 6.65s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.34
# Epoch 5: 8.40s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 6: 10.11s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.30
# Epoch 7: 11.85s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 8: 13.58s, train acc=0.94, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 9: 15.48s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.27
# Epoch 10: 17.42s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 11: 19.00s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 12: 20.55s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.24
# Epoch 13: 22.10s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.23
# Epoch 14: 23.62s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 15: 25.21s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 16: 26.77s, train acc=0.96, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 17: 28.42s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 18: 29.99s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 19: 31.64s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.20
# Epoch 20: 33.27s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.20
#
# Test acc=0.95, Test loss=0.20
#
#
# Activation: leaky_relu, Optimizer: sgd, Learning Rate: 0.001
# Epoch 1: 1.70s, train acc=0.26, train loss=2.26, validation acc=0.26, validation loss=2.26
# Epoch 2: 3.60s, train acc=0.39, train loss=2.13, validation acc=0.39, validation loss=2.13
# Epoch 3: 5.49s, train acc=0.46, train loss=1.96, validation acc=0.46, validation loss=1.96
# Epoch 4: 7.40s, train acc=0.51, train loss=1.79, validation acc=0.51, validation loss=1.79
# Epoch 5: 9.12s, train acc=0.55, train loss=1.63, validation acc=0.54, validation loss=1.64
# Epoch 6: 10.85s, train acc=0.56, train loss=1.51, validation acc=0.56, validation loss=1.51
# Epoch 7: 12.71s, train acc=0.58, train loss=1.38, validation acc=0.57, validation loss=1.39
# Epoch 8: 14.48s, train acc=0.69, train loss=1.23, validation acc=0.69, validation loss=1.24
# Epoch 9: 16.23s, train acc=0.74, train loss=1.08, validation acc=0.73, validation loss=1.09
# Epoch 10: 17.93s, train acc=0.76, train loss=0.94, validation acc=0.75, validation loss=0.95
# Epoch 11: 20.07s, train acc=0.77, train loss=0.81, validation acc=0.76, validation loss=0.83
# Epoch 12: 22.03s, train acc=0.86, train loss=0.61, validation acc=0.85, validation loss=0.63
# Epoch 13: 24.28s, train acc=0.87, train loss=0.53, validation acc=0.86, validation loss=0.56
# Epoch 14: 26.03s, train acc=0.88, train loss=0.49, validation acc=0.87, validation loss=0.51
# Epoch 15: 27.71s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 16: 29.43s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 17: 31.20s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 18: 32.83s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 19: 34.59s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 20: 36.30s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
#
# Test acc=0.89, Test loss=0.40
#
#
# Activation: leaky_relu, Optimizer: momentum, Learning Rate: 0.01
# Epoch 1: 1.96s, train acc=0.80, train loss=0.76, validation acc=0.80, validation loss=0.78
# Epoch 2: 3.93s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 3: 5.80s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.37
# Epoch 4: 7.75s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.33
# Epoch 5: 9.72s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 6: 11.71s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 7: 13.78s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 8: 15.92s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.26
# Epoch 9: 18.01s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 10: 20.55s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 11: 22.49s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 12: 24.62s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 13: 26.57s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 14: 28.59s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 15: 30.57s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 16: 32.46s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 17: 34.43s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 18: 36.45s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 19: 38.40s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 20: 40.40s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
#
# Test acc=0.95, Test loss=0.17
#
#
# Activation: leaky_relu, Optimizer: momentum, Learning Rate: 0.001
# Epoch 1: 2.12s, train acc=0.37, train loss=2.18, validation acc=0.36, validation loss=2.19
# Epoch 2: 4.42s, train acc=0.42, train loss=2.00, validation acc=0.41, validation loss=2.01
# Epoch 3: 6.24s, train acc=0.53, train loss=1.76, validation acc=0.52, validation loss=1.78
# Epoch 4: 8.08s, train acc=0.60, train loss=1.52, validation acc=0.58, validation loss=1.55
# Epoch 5: 9.89s, train acc=0.65, train loss=1.29, validation acc=0.63, validation loss=1.31
# Epoch 6: 11.68s, train acc=0.73, train loss=1.13, validation acc=0.71, validation loss=1.15
# Epoch 7: 13.54s, train acc=0.76, train loss=1.02, validation acc=0.74, validation loss=1.04
# Epoch 8: 15.72s, train acc=0.77, train loss=0.93, validation acc=0.76, validation loss=0.96
# Epoch 9: 17.76s, train acc=0.78, train loss=0.87, validation acc=0.77, validation loss=0.90
# Epoch 10: 19.75s, train acc=0.79, train loss=0.82, validation acc=0.78, validation loss=0.85
# Epoch 11: 21.78s, train acc=0.79, train loss=0.77, validation acc=0.78, validation loss=0.80
# Epoch 12: 23.78s, train acc=0.80, train loss=0.73, validation acc=0.79, validation loss=0.76
# Epoch 13: 25.77s, train acc=0.80, train loss=0.70, validation acc=0.79, validation loss=0.73
# Epoch 14: 27.74s, train acc=0.80, train loss=0.67, validation acc=0.79, validation loss=0.70
# Epoch 15: 29.67s, train acc=0.81, train loss=0.64, validation acc=0.80, validation loss=0.68
# Epoch 16: 31.69s, train acc=0.81, train loss=0.62, validation acc=0.80, validation loss=0.65
# Epoch 17: 33.84s, train acc=0.81, train loss=0.60, validation acc=0.80, validation loss=0.63
# Epoch 18: 35.87s, train acc=0.81, train loss=0.58, validation acc=0.80, validation loss=0.62
# Epoch 19: 37.79s, train acc=0.81, train loss=0.56, validation acc=0.80, validation loss=0.60
# Epoch 20: 39.77s, train acc=0.82, train loss=0.55, validation acc=0.81, validation loss=0.58
#
# Test acc=0.81, Test loss=0.58
#
#
# Activation: leaky_relu, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 2.71s, train acc=0.94, train loss=0.21, validation acc=0.92, validation loss=0.26
# Epoch 2: 5.56s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.19
# Epoch 3: 8.97s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.19
# Epoch 4: 11.85s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 5: 14.60s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.19
# Epoch 6: 17.46s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.16
# Epoch 7: 20.27s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.15
# Epoch 8: 23.29s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.17
# Epoch 9: 26.00s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.15
# Epoch 10: 32.29s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.14
# Epoch 11: 35.13s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.15
# Epoch 12: 37.90s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.15
# Epoch 13: 40.55s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.17
# Epoch 14: 43.29s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.15
# Epoch 15: 46.04s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 16: 48.71s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.17
# Epoch 17: 51.30s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.18
# Epoch 18: 53.97s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.18
# Epoch 19: 56.65s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 20: 59.41s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.18
#
# Test acc=0.96, Test loss=0.18
#
#
# Activation: leaky_relu, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 2.78s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 2: 5.57s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 3: 8.37s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 4: 11.17s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 5: 13.93s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 6: 16.67s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 7: 19.47s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 8: 22.25s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 9: 26.37s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 10: 29.10s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 11: 31.95s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 12: 34.94s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 13: 39.63s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 14: 42.46s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 15: 45.26s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 16: 51.20s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 17: 53.96s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 18: 56.74s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 19: 61.57s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 20: 64.53s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.12
#
# Test acc=0.98, Test loss=0.12
#
#
# Activation: selu, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 2.16s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 2: 4.36s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 3: 6.45s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 4: 9.61s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 5: 11.79s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 14.03s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 7: 17.16s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.28
# Epoch 8: 19.23s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.27
# Epoch 9: 21.44s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.26
# Epoch 10: 23.56s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.25
# Epoch 11: 26.02s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 12: 28.21s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 13: 30.27s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.23
# Epoch 14: 32.36s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.22
# ...
# Epoch 18: 42.40s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.36
# Epoch 19: 44.81s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 20: 47.17s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
#
# Test acc=0.90, Test loss=0.35
#
#
# Activation: selu, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 3.15s, train acc=0.35, train loss=4.76, validation acc=0.34, validation loss=4.94
# Epoch 2: 6.64s, train acc=0.34, train loss=4.51, validation acc=0.32, validation loss=4.66
# Epoch 3: 9.71s, train acc=0.34, train loss=4.20, validation acc=0.33, validation loss=4.36
# Epoch 4: 12.80s, train acc=0.30, train loss=5.36, validation acc=0.28, validation loss=5.58
# Epoch 5: 15.79s, train acc=0.19, train loss=8.74, validation acc=0.18, validation loss=8.98
# Epoch 6: 18.90s, train acc=0.22, train loss=8.79, validation acc=0.22, validation loss=9.01
# Epoch 7: 21.89s, train acc=0.14, train loss=13.46, validation acc=0.14, validation loss=13.61
# Epoch 8: 24.89s, train acc=0.20, train loss=11.46, validation acc=0.19, validation loss=11.65
# Epoch 9: 27.93s, train acc=0.21, train loss=11.93, validation acc=0.20, validation loss=12.14
# Epoch 10: 31.64s, train acc=0.24, train loss=11.01, validation acc=0.23, validation loss=11.20
# Epoch 11: 38.03s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 12: 41.11s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 13: 44.15s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 14: 47.15s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 15: 50.16s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 16: 56.48s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 17: 59.44s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.32
# Epoch 18: 62.41s, train acc=0.10, train loss=19.23, validation acc=0.10, validation loss=19.31
# Epoch 19: 65.34s, train acc=0.10, train loss=19.22, validation acc=0.10, validation loss=19.31
# Epoch 20: 68.30s, train acc=0.10, train loss=19.22, validation acc=0.10, validation loss=19.31
#
# Test acc=0.10, Test loss=19.31
#
#
# Activation: selu, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 3.10s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 2: 9.29s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 3: 12.27s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.18
# Epoch 4: 18.55s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.16
# Epoch 5: 21.61s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.15
# Epoch 6: 24.80s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 7: 27.80s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.13
# Epoch 8: 30.91s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 9: 33.99s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 10: 37.15s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 11: 40.25s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 12: 43.31s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 13: 46.35s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 14: 49.44s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 15: 55.18s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 16: 58.27s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 17: 61.39s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 18: 64.50s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 19: 67.59s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 20: 70.70s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
#
# Test acc=0.97, Test loss=0.11
#
#
# Activation: elu, Optimizer: sgd, Learning Rate: 0.01
# Epoch 1: 2.06s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.48
# Epoch 2: 4.14s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 6.11s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 8.20s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 5: 10.27s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.33
# Epoch 6: 12.27s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 7: 14.25s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 8: 16.37s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.30
# Epoch 9: 18.49s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 10: 20.54s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 11: 22.56s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 12: 24.69s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.27
# Epoch 13: 26.74s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 14: 28.83s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 15: 30.88s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 16: 32.88s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 17: 35.04s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 18: 37.11s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 19: 39.21s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 20: 41.24s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
#
# Test acc=0.94, Test loss=0.21
#
#
# Activation: elu, Optimizer: sgd, Learning Rate: 0.001
# Epoch 1: 2.13s, train acc=0.67, train loss=1.71, validation acc=0.65, validation loss=1.72
# Epoch 2: 4.15s, train acc=0.76, train loss=1.25, validation acc=0.75, validation loss=1.26
# Epoch 3: 6.20s, train acc=0.81, train loss=0.95, validation acc=0.80, validation loss=0.97
# Epoch 4: 8.37s, train acc=0.83, train loss=0.78, validation acc=0.82, validation loss=0.80
# Epoch 5: 10.39s, train acc=0.85, train loss=0.67, validation acc=0.84, validation loss=0.69
# Epoch 6: 13.55s, train acc=0.86, train loss=0.59, validation acc=0.85, validation loss=0.62
# Epoch 7: 15.58s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.57
# Epoch 8: 17.72s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.53
# Epoch 9: 19.86s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.51
# Epoch 10: 22.03s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 11: 24.12s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.47
# Epoch 12: 26.15s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 13: 28.29s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 14: 30.47s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 15: 32.51s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 16: 34.62s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 17: 36.68s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 38.79s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 19: 40.81s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 42.78s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
#
# Test acc=0.89, Test loss=0.39
#
#
# Activation: elu, Optimizer: momentum, Learning Rate: 0.01
# Epoch 1: 2.33s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.49
# Epoch 2: 4.66s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 7.04s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.36
# Epoch 4: 9.30s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.34
# Epoch 5: 11.48s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 6: 13.62s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 7: 15.95s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 8: 18.17s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.30
# Epoch 9: 20.41s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 10: 22.65s, train acc=0.94, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 11: 24.94s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.27
# Epoch 12: 28.70s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 13: 30.94s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 14: 33.26s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 15: 35.58s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 16: 37.85s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 17: 40.16s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 18: 42.50s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 19: 44.86s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 20: 47.35s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.21
#
# Test acc=0.94, Test loss=0.21
#
#
# Activation: elu, Optimizer: momentum, Learning Rate: 0.001
# Epoch 1: 2.34s, train acc=0.66, train loss=1.62, validation acc=0.64, validation loss=1.63
# Epoch 2: 4.72s, train acc=0.77, train loss=1.15, validation acc=0.76, validation loss=1.17
# Epoch 3: 7.00s, train acc=0.82, train loss=0.88, validation acc=0.81, validation loss=0.90
# Epoch 4: 9.26s, train acc=0.84, train loss=0.72, validation acc=0.83, validation loss=0.75
# Epoch 5: 11.57s, train acc=0.85, train loss=0.63, validation acc=0.85, validation loss=0.65
# Epoch 6: 13.79s, train acc=0.86, train loss=0.56, validation acc=0.85, validation loss=0.59
# Epoch 7: 16.03s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 8: 18.24s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 9: 20.54s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 10: 22.83s, train acc=0.89, train loss=0.44, validation acc=0.87, validation loss=0.47
# Epoch 11: 25.15s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 12: 27.42s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 13: 29.69s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 14: 31.91s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 15: 34.16s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 16: 36.34s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 17: 38.60s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 40.75s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 42.99s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 45.28s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
#
#
# Activation: elu, Optimizer: adam, Learning Rate: 0.01
# Epoch 1: 2.93s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.30
# Epoch 2: 5.98s, train acc=0.82, train loss=0.64, validation acc=0.81, validation loss=0.71
# Epoch 3: 8.99s, train acc=0.84, train loss=0.64, validation acc=0.83, validation loss=0.74
# Epoch 4: 12.01s, train acc=0.74, train loss=1.01, validation acc=0.72, validation loss=1.10
# Epoch 5: 15.00s, train acc=0.76, train loss=1.01, validation acc=0.74, validation loss=1.09
# Epoch 6: 18.02s, train acc=0.51, train loss=3.77, validation acc=0.49, validation loss=3.96
# Epoch 7: 21.05s, train acc=0.45, train loss=3.96, validation acc=0.44, validation loss=4.09
# Epoch 8: 24.11s, train acc=0.38, train loss=5.17, validation acc=0.36, validation loss=5.38
# Epoch 9: 27.18s, train acc=0.33, train loss=6.87, validation acc=0.32, validation loss=7.07
# Epoch 10: 30.18s, train acc=0.33, train loss=6.71, validation acc=0.32, validation loss=6.90
# Epoch 11: 33.27s, train acc=0.33, train loss=6.50, validation acc=0.31, validation loss=6.68
# Epoch 12: 36.33s, train acc=0.15, train loss=12.81, validation acc=0.14, validation loss=13.05
# Epoch 13: 39.27s, train acc=0.13, train loss=13.30, validation acc=0.12, validation loss=13.58
# Epoch 14: 42.37s, train acc=0.13, train loss=13.32, validation acc=0.12, validation loss=13.60
# Epoch 15: 45.35s, train acc=0.13, train loss=13.35, validation acc=0.12, validation loss=13.63
# Epoch 16: 48.52s, train acc=0.13, train loss=13.37, validation acc=0.12, validation loss=13.65
# Epoch 17: 51.53s, train acc=0.13, train loss=13.41, validation acc=0.12, validation loss=13.69
# Epoch 18: 54.80s, train acc=0.13, train loss=13.45, validation acc=0.12, validation loss=13.73
# Epoch 19: 57.76s, train acc=0.12, train loss=13.49, validation acc=0.11, validation loss=13.77
# Epoch 20: 60.67s, train acc=0.12, train loss=13.54, validation acc=0.11, validation loss=13.82
#
# Test acc=0.11, Test loss=13.82
#
#
# Activation: elu, Optimizer: adam, Learning Rate: 0.001
# Epoch 1: 3.11s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 2: 6.18s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 3: 9.23s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 4: 14.53s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 5: 17.76s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 6: 20.91s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.12
# Epoch 7: 24.10s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 8: 27.64s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 9: 30.84s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 10: 33.95s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 11: 37.06s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 12: 40.28s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 13: 43.44s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 14: 46.62s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 15: 49.60s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 16: 52.79s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 17: 55.92s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 18: 59.00s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 19: 62.60s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 20: 65.65s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
#
# Test acc=0.97, Test loss=0.11
#
#
# Best model: ('leaky_relu', 'adam', 0.001), Accuracy: 0.9757, Loss: 0.11586540984514382

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = input_data.squeeze()[:-1]

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros((num_relus, x_points.shape[0]))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS
    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j+1] - target_labels[j]) / (input_data[j+1] - input_data[j])
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()
    self.activation_functions = {
        'relu': nn.ReLU,
        'tanh': nn.Tanh,
        'sigmoid': nn.Sigmoid,
        'softmax': nn.Softmax,
        'leaky_relu': nn.LeakyReLU,
        'elu': nn.ELU,
        'selu': nn.SELU
    }
    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
        hidden_layer = nn.Linear(in_num, hidden_unit_nums[i])
        self.mlp.add_module(f'Hidden_Linear_{i}', hidden_layer)
        self.mlp.add_module(f'Activation_{i}', self.activation_functions[activation_fn.lower()]())
        in_num = hidden_unit_nums[i]
    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_features = (poly_degree+1) * (poly_degree+2) // 2 - 1
    poly_X = torch.zeros((X.shape[0], num_features))
    column = 0
    for i in range(poly_degree+1):
        for j in range(poly_degree+1):
            if 0 < i+j <= poly_degree:
                poly_X[:, column] = X[:, 0]**i * X[:, 1]**j
                column += 1
    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.97
# Accuracy on the 800 testing samples: 69.38
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch('relu', 2, [128], K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100


_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 98.38
# Accuracy on the 800 testing samples: 98.75
